# %%
import pandas as pd
import numpy as np
from scipy.sparse.linalg import svds

# %%
def getratingmat( df_rating ):
    df = df_rating.pivot(index='movieId', columns='userId', values='rating')
    df = df.fillna(0)
    df.index.name = 'Movie ID'
    df.columns.name = 'User ID'
    Y = df.as_matrix()
    R = ( Y > 0. ).astype(int)
    return( df, Y, R );

def normalizeratings2( Y, R ):
    Y_sum = np.sum( Y, axis = 0 )
    R_sum = np.sum( R, axis = 0 )
    Y_mean = Y_sum / R_sum
    Y_norm = np.zeros( Y.shape )
    for i in range( Y.shape[1] ):
        j = np.where( R[:,i] == 1 )
        Y_norm[j,i] = Y[j,i] - Y_mean[i]       
    return( Y_norm, Y_mean );

def getrecommendation( df_pred, df_mov, df_small, userId, top_n = 10 ):
    df_user = ( df_small.loc[ df_small['userId'] == userId ].
               merge(df_mov, on = 'movieId').
               reset_index(drop = True).
               sort_values('rating', ascending=False) )
    df_userp = df_pred[ userId ].reset_index()
    df_userp.columns = [ 'movieId', 'prediction' ]
    df_p = ( df_userp[~df_userp['movieId'].isin(df_user['movieId'])].
            merge(df_mov, on = 'movieId' ).
            sort_values('prediction', ascending=False) )
    return( df_p.head(top_n) )

# %%
df_small = pd.read_csv('../movielens_small/ratings_clean.csv')
df_mov = pd.read_csv( '../movielens_small/metadata_clean.csv' )

# %%
df, Y, R = getratingmat( df_small );

# %%
Y_norm, Y_mean = normalizeratings2( Y, R );

# %%
U, sigma, Vt = svds(Y_norm, k = 50)
sigma = np.diag(sigma)

# %%
all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + Y_mean
df_pred = pd.DataFrame(all_user_predicted_ratings, columns = df.columns, index = df.index)

# %%
getrecommendation( df_pred, df_mov, df_small, 50 )
# Out:
#       movieId  prediction  index  tmdbId                     title  \
# 265       318    3.737711    284     278  The Shawshank Redemption
# 482       593    3.499678    525     274  The Silence of the Lambs
# 1540     2028    3.478345   1586     857       Saving Private Ryan
# 184       223    3.435785    196    2292                    Clerks
# 1430     1917    3.429687   1476      95                Armageddon
# 247       293    3.422716    263     101    Leon: The Professional
# 218       260    3.414686    232      11                 Star Wars
# 2012     2571    3.408879   2058     603                The Matrix
# 1282     1676    3.402277   1328     563         Starship Troopers
# 2480     3147    3.401920   2526     497            The Green Mile
#
#       vote_average  vote_count  \
# 265            8.5        8358
# 482            8.1        4549
# 1540           7.9        5148
# 184            7.4         769
# 1430           6.5        2540
# 247            8.2        4293
# 218            8.1        6778
# 2012           7.9        9079
# 1282           6.7        1584
# 2480           8.2        4166
#
#                                                    cast          director  \
# 265   ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...    Frank Darabont
# 482   ['Jodie Foster', 'Anthony Hopkins', 'Scott Gle...    Jonathan Demme
# 1540  ['Tom Hanks', 'Matt Damon', 'Vin Diesel', 'Tom...  Steven Spielberg
# 184   ["Brian O'Halloran", 'Jeff Anderson', 'Jason M...       Kevin Smith
# 1430  ['Bruce Willis', 'Billy Bob Thornton', 'Ben Af...       Michael Bay
# 247   ['Jean Reno', 'Natalie Portman', 'Gary Oldman'...        Luc Besson
# 218   ['Mark Hamill', 'Harrison Ford', 'Carrie Fishe...      George Lucas
# 2012  ['Keanu Reeves', 'Laurence Fishburne', 'Carrie...    Lana Wachowski
# 1282  ['Casper Van Dien', 'Dina Meyer', 'Denise Rich...    Paul Verhoeven
# 2480  ['Tom Hanks', 'Michael Clarke Duncan', 'David ...    Frank Darabont
#
#                                                keywords  \
# 265   ['prison', 'corruption', 'police brutality', '...
# 482   ['based on novel', 'psychopath', 'horror', 'su...
# 1540  ['war crimes', 'self sacrifice', 'war veteran'...
# 184      ['salesclerk', 'loser', 'aftercreditsstinger']
# 1430  ['saving the world', 'paris', 'moon', 'catacly...
# 247   ['new york', 'corruption', 'assassin', 'police...
# 218   ['android', 'galaxy', 'hermit', 'death star', ...
# 2012  ['saving the world', 'artificial intelligence'...
# 1282  ['moon', 'asteroid', 'space marine', 'intellig...
# 2480  ['southern usa', 'black people', 'mentally dis...
#
#                                                  genres
# 265                                  ['Drama', 'Crime']
# 482                      ['Crime', 'Drama', 'Thriller']
# 1540                        ['Drama', 'History', 'War']
# 184                                          ['Comedy']
# 1430  ['Action', 'Thriller', 'Science Fiction', 'Adv...
# 247                      ['Thriller', 'Crime', 'Drama']
# 218          ['Adventure', 'Action', 'Science Fiction']
# 2012                      ['Action', 'Science Fiction']
# 1282  ['Adventure', 'Action', 'Thriller', 'Science F...
# 2480                      ['Fantasy', 'Drama', 'Crime']
