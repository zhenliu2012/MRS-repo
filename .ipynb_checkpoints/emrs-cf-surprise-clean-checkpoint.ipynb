# %%
import pandas as pd
from collections import defaultdict
from surprise import SVD
from surprise import Dataset
from surprise import Reader

# %%
def getprediction( predictions, userId ):
    user_pred = []
    for uid, iid, true_r, est, _ in predictions:
        if uid == userId :
            user_pred.append( (iid, est) )
    df_userp = pd.DataFrame( user_pred, columns = [ 'movieId', 'prediction'] )
    df_userp['movieId'] = df_userp['movieId'].astype(int)
    return( df_userp )

# %%
#load data
df_small = pd.read_csv('../movielens_small/ratings_small.csv')
df_mov = pd.read_csv( '../movielens_small/movies.csv' )
#df_small.head()

# %%
reader = Reader()
rating_data = Dataset.load_from_df(df_small[['userId', 'movieId', 'rating']], reader)
#rating_data.split(n_folds=5)

# %%
algo = SVD( biased = False, n_factors = 60, n_epochs = 50 )
trainset = rating_data.build_full_trainset()
algo.fit(trainset)

# %%
# Then predict ratings for all pairs (u, i) that are not in the training set.
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

# %%
user_id = 668

# %%
df_userp = getprediction( predictions, user_id )
#df_userp.head()
df_userp = ( df_userp. join(df_mov.set_index('movieId'), on = 'movieId' ).
            sort_values('prediction', ascending=False) )
df_userp.head(15)
# Out:
#       movieId  prediction                           title  \
# 153       858    4.885717           Godfather, The (1972)
# 117      2858    4.744878          American Beauty (1999)
# 24         50    4.716306      Usual Suspects, The (1995)
# 78        527    4.696700         Schindler's List (1993)
# 2191      905    4.642328    It Happened One Night (1934)
# 381      1276    4.631842           Cool Hand Luke (1967)
# 2137      898    4.601359  Philadelphia Story, The (1940)
# 1021     3462    4.542967             Modern Times (1936)
# 376       111    4.515132              Taxi Driver (1976)
# 118      2959    4.507248               Fight Club (1999)
# 192      1278    4.475462       Young Frankenstein (1974)
# 180      1219    4.456103                   Psycho (1960)
# 5        1263    4.446371         Deer Hunter, The (1978)
# 89        590    4.421023       Dances with Wolves (1990)
# 356      5995    4.417853             Pianist, The (2002)
#
#                            genres
# 153                   Crime|Drama
# 117                 Drama|Romance
# 24         Crime|Mystery|Thriller
# 78                      Drama|War
# 2191               Comedy|Romance
# 381                         Drama
# 2137         Comedy|Drama|Romance
# 1021         Comedy|Drama|Romance
# 376          Crime|Drama|Thriller
# 118   Action|Crime|Drama|Thriller
# 192                Comedy|Fantasy
# 180                  Crime|Horror
# 5                       Drama|War
# 89        Adventure|Drama|Western
# 356                     Drama|War

# %%
df_user = ( df_small.loc[ df_small['userId'] == user_id ].
           join(df_mov.set_index('movieId'),on = 'movieId').
           reset_index(drop = True).
           sort_values('rating', ascending=False) )
df_user
# Out:
#     userId  movieId  rating  timestamp  \
# 0      668      296     5.0  993613478
# 2      668      593     5.0  993613478
# 3      668      608     5.0  993613478
# 14     668     2997     5.0  993613478
# 13     668     2908     5.0  993613415
# 6      668     1213     5.0  993613359
# 7      668     1221     5.0  993613196
# 11     668     2324     5.0  993613359
# 1      668      318     4.0  993613478
# 9      668     1358     4.0  993613415
# 8      668     1233     4.0  993613415
# 18     668     4012     3.0  993613196
# 12     668     2501     3.0  993613415
# 5      668     1089     3.0  993613415
# 4      668      720     3.0  993613415
# 15     668     3000     3.0  993613196
# 16     668     3039     3.0  993613196
# 17     668     3213     3.0  993613359
# 10     668     1490     1.0  993613196
# 19     668     6425     1.0  993613478
#
#                                                 title  \
# 0                                 Pulp Fiction (1994)
# 2                    Silence of the Lambs, The (1991)
# 3                                        Fargo (1996)
# 14                        Being John Malkovich (1999)
# 13                              Boys Don't Cry (1999)
# 6                                   Goodfellas (1990)
# 7                      Godfather: Part II, The (1974)
# 11         Life Is Beautiful (La Vita è bella) (1997)
# 1                    Shawshank Redemption, The (1994)
# 9                                  Sling Blade (1996)
# 8                        Boot, Das (Boat, The) (1981)
# 18                                   Punchline (1988)
# 12                                 October Sky (1999)
# 5                               Reservoir Dogs (1992)
# 4   Wallace & Gromit: The Best of Aardman Animatio...
# 15           Princess Mononoke (Mononoke-hime) (1997)
# 16                              Trading Places (1983)
# 17                Batman: Mask of the Phantasm (1993)
# 10                                     B*A*P*S (1997)
# 19               6th Man, The (Sixth Man, The) (1997)
#
#                                       genres
# 0                Comedy|Crime|Drama|Thriller
# 2                      Crime|Horror|Thriller
# 3                Comedy|Crime|Drama|Thriller
# 14                      Comedy|Drama|Fantasy
# 13                                     Drama
# 6                                Crime|Drama
# 7                                Crime|Drama
# 11                  Comedy|Drama|Romance|War
# 1                                Crime|Drama
# 9                                      Drama
# 8                           Action|Drama|War
# 18                              Comedy|Drama
# 12                                     Drama
# 5                     Crime|Mystery|Thriller
# 4                 Adventure|Animation|Comedy
# 15  Action|Adventure|Animation|Drama|Fantasy
# 16                                    Comedy
# 17                        Animation|Children
# 10                                    Comedy
# 19                                    Comedy
