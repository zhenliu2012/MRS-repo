# %%
import pandas as pd
import numpy as np
from scipy.sparse.linalg import svds

# %%
def getratingmat( df_rating ):
    df = df_rating.pivot(index='movieId', columns='userId', values='rating')
    df = df.fillna(0)
    df.index.name = 'Movie ID'
    df.columns.name = 'User ID'
    Y = df.as_matrix()
    R = ( Y > 0. ).astype(int)
    print( 'convert rating dataframe to rating matrix for gradient descent')
    return( df, Y, R );

def normalizeratings2( Y, R ):
    Y_sum = np.sum( Y, axis = 0 )
    R_sum = np.sum( R, axis = 0 )
    Y_mean = Y_sum / R_sum
    Y_norm = np.zeros( Y.shape )
    for i in range( Y.shape[1] ):
        j = np.where( R[:,i] == 1 )
        Y_norm[j,i] = Y[j,i] - Y_mean[i]       
    return( Y_norm, Y_mean );

def getrecommendation( df_pred, df_mov, df_small, userId, top_n = 15 ):
    df_user = ( df_small.loc[ df_small['userId'] == userId ].
               join(df_mov.set_index('movieId'),on = 'movieId').
               reset_index(drop = True).
               sort_values('rating', ascending=False) )
    display( df_user )
    df_userp = df_pred[ userId ].reset_index()
    df_userp.columns = [ 'movieId', 'prediction' ]
    df_p = ( df_userp[~df_userp['movieId'].isin(df_user['movieId'])].
            join(df_mov.set_index('movieId'), on = 'movieId' ).
            sort_values('prediction', ascending=False) )
    return( df_p.head(top_n) )

# %%
df_small = pd.read_csv('../movielens_small/ratings_small.csv').drop('timestamp', axis=1)
df_mov = pd.read_csv( '../movielens_small/movies.csv' )

# %%
df, Y, R = getratingmat( df_small );
# Out:
# convert rating dataframe to rating matrix for gradient descent

# %%
Y_norm, Y_mean = normalizeratings2( Y, R );

# %%
U, sigma, Vt = svds(Y_norm, k = 100)
sigma = np.diag(sigma)

# %%
all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + Y_mean
df_pred = pd.DataFrame(all_user_predicted_ratings, columns = df.columns, index = df.index)

# %%
getrecommendation( df_pred, df_mov, df_small, 668 )
# Out:
#     userId  movieId  rating  \
# 0      668      296     5.0
# 2      668      593     5.0
# 3      668      608     5.0
# 14     668     2997     5.0
# 13     668     2908     5.0
# 6      668     1213     5.0
# 7      668     1221     5.0
# 11     668     2324     5.0
# 1      668      318     4.0
# 9      668     1358     4.0
# 8      668     1233     4.0
# 18     668     4012     3.0
# 12     668     2501     3.0
# 5      668     1089     3.0
# 4      668      720     3.0
# 15     668     3000     3.0
# 16     668     3039     3.0
# 17     668     3213     3.0
# 10     668     1490     1.0
# 19     668     6425     1.0
#
#                                                 title  \
# 0                                 Pulp Fiction (1994)
# 2                    Silence of the Lambs, The (1991)
# 3                                        Fargo (1996)
# 14                        Being John Malkovich (1999)
# 13                              Boys Don't Cry (1999)
# 6                                   Goodfellas (1990)
# 7                      Godfather: Part II, The (1974)
# 11         Life Is Beautiful (La Vita è bella) (1997)
# 1                    Shawshank Redemption, The (1994)
# 9                                  Sling Blade (1996)
# 8                        Boot, Das (Boat, The) (1981)
# 18                                   Punchline (1988)
# 12                                 October Sky (1999)
# 5                               Reservoir Dogs (1992)
# 4   Wallace & Gromit: The Best of Aardman Animatio...
# 15           Princess Mononoke (Mononoke-hime) (1997)
# 16                              Trading Places (1983)
# 17                Batman: Mask of the Phantasm (1993)
# 10                                     B*A*P*S (1997)
# 19               6th Man, The (Sixth Man, The) (1997)
#
#                                       genres
# 0                Comedy|Crime|Drama|Thriller
# 2                      Crime|Horror|Thriller
# 3                Comedy|Crime|Drama|Thriller
# 14                      Comedy|Drama|Fantasy
# 13                                     Drama
# 6                                Crime|Drama
# 7                                Crime|Drama
# 11                  Comedy|Drama|Romance|War
# 1                                Crime|Drama
# 9                                      Drama
# 8                           Action|Drama|War
# 18                              Comedy|Drama
# 12                                     Drama
# 5                     Crime|Mystery|Thriller
# 4                 Adventure|Animation|Comedy
# 15  Action|Adventure|Animation|Drama|Fantasy
# 16                                    Comedy
# 17                        Animation|Children
# 10                                    Comedy
# 19                                    Comedy
#       movieId  prediction                                              title  \
# 695       858    4.231737                              Godfather, The (1972)
# 48         50    3.984040                         Usual Suspects, The (1995)
# 455       509    3.947973                                  Piano, The (1993)
# 472       527    3.935225                            Schindler's List (1993)
# 15         16    3.906124                                      Casino (1995)
# 203       231    3.892004             Dumb & Dumber (Dumb and Dumber) (1994)
# 1116     1376    3.885298               Star Trek IV: The Voyage Home (1986)
# 2532     3148    3.877128                      Cider House Rules, The (1999)
# 2288     2858    3.875766                             American Beauty (1999)
# 232       260    3.873094          Star Wars: Episode IV - A New Hope (1977)
# 3845     4963    3.870673                              Ocean's Eleven (2001)
# 5393     8376    3.864399                           Napoleon Dynamite (2004)
# 1100     1356    3.863096                    Star Trek: First Contact (1996)
# 3854     4973    3.860897  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 866      1073    3.859082         Willy Wonka & the Chocolate Factory (1971)
#
#                                 genres
# 695                        Crime|Drama
# 48              Crime|Mystery|Thriller
# 455                      Drama|Romance
# 472                          Drama|War
# 15                         Crime|Drama
# 203                   Adventure|Comedy
# 1116           Adventure|Comedy|Sci-Fi
# 2532                             Drama
# 2288                     Drama|Romance
# 232            Action|Adventure|Sci-Fi
# 3845                    Crime|Thriller
# 5393                            Comedy
# 1100  Action|Adventure|Sci-Fi|Thriller
# 3854                    Comedy|Romance
# 866    Children|Comedy|Fantasy|Musical
