# %%
import pandas as pd
from collections import defaultdict
from surprise import SVD
from surprise import Dataset
from surprise import Reader
import ast
from surprise.model_selection import cross_validate

# %%
def getprediction( predictions, userId ):
    user_pred = []
    for uid, iid, true_r, est, _ in predictions:
        if uid == userId :
            user_pred.append( (iid, est) )
    df_userp = pd.DataFrame( user_pred, columns = [ 'movieId', 'prediction'] )
    df_userp['movieId'] = df_userp['movieId'].astype(int)
    return( df_userp )

# %%
#load data
df_small = pd.read_csv('../movielens_small/ratings_clean.csv')
df_md_small = pd.read_csv( '../movielens_small/metadata_clean.csv' )
#df_small.head()

# %%
df_md_small['genres'] = df_md_small['genres'].apply(ast.literal_eval)
df_md_small['cast'] = df_md_small['cast'].apply(ast.literal_eval)
df_md_small['keywords'] = df_md_small['keywords'].apply(ast.literal_eval)

# %%
reader = Reader()
rating_data = Dataset.load_from_df(df_small[['userId', 'movieId', 'rating']], reader)

# %%
algo = SVD( biased = True, n_factors = 100, n_epochs = 30 )
# Run 5-fold cross-validation and print results.
cross_validate(algo, rating_data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9014  0.9020  0.8865  0.8984  0.9039  0.8985  0.0062
# MAE (testset)     0.6960  0.6937  0.6826  0.6936  0.6946  0.6921  0.0048
# Fit time          19.81   20.26   20.38   20.42   10.24   18.22   4.00
# Test time         0.59    0.46    0.59    0.33    0.15    0.42    0.17
# {'fit_time': (19.80711007118225,
#   20.261728048324585,
#   20.38376808166504,
#   20.423498392105103,
#   10.242048025131226),
#  'test_mae': array([ 0.69600512,  0.69365111,  0.68257576,  0.69357652,  0.69456018]),
#  'test_rmse': array([ 0.90137827,  0.9020386 ,  0.88651692,  0.89837282,  0.90394924]),
#  'test_time': (0.5885262489318848,
#   0.4564390182495117,
#   0.5860190391540527,
#   0.3281216621398926,
#   0.1526811122894287)}

# %%
# build trainset
trainset = rating_data.build_full_trainset()
algo.fit(trainset)

# %%
# predict ratings for all pairs (u, i) that are not in the training set.
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

# %%
user_id = 50

# %%
df_userp = getprediction( predictions, user_id )
#df_userp.head()
df_userp = ( df_userp. join(df_md_small.set_index('movieId'), on = 'movieId' ).
            sort_values('prediction', ascending=False) )
df_userp.head(10)
# Out:
#       movieId  prediction  index  tmdbId                             title  \
# 696       922    4.441198    740     599                  Sunset Boulevard
# 994      3462    4.420965   2759    3082                      Modern Times
# 4        1172    4.412912    927   11216                   Cinema Paradiso
# 1502    57669    4.385885   6864    8321                         In Bruges
# 77       1197    4.365669    950    2493                The Princess Bride
# 389       534    4.364211    478   10445                       Shadowlands
# 729      1217    4.338820    969   11645                               Ran
# 71        318    4.332526    284     278          The Shawshank Redemption
# 740      1254    4.332362   1004    3090  The Treasure of the Sierra Madre
# 1499    56782    4.330872   6837    7345               There Will Be Blood
#
#       vote_average  vote_count  \
# 696            8.2         533
# 994            8.1         881
# 4              8.2         834
# 1502           7.4        1414
# 77             7.6        1518
# 389            6.8          61
# 729            7.9         349
# 71             8.5        8358
# 740            7.9         285
# 1499           7.9        1581
#
#                                                    cast              director  \
# 696   [William Holden, Gloria Swanson, Erich von Str...          Billy Wilder
# 994   [Charlie Chaplin, Paulette Goddard, Henry Berg...       Charlie Chaplin
# 4     [Philippe Noiret, Jacques Perrin, Marco Leonar...    Giuseppe Tornatore
# 1502  [Colin Farrell, Brendan Gleeson, Ralph Fiennes...       Martin McDonagh
# 77    [Cary Elwes, Robin Wright, Mandy Patinkin, And...            Rob Reiner
# 389   [Anthony Hopkins, Debra Winger, John Wood, Jul...  Richard Attenborough
# 729   [Akira Terao, Jinpachi Nezu, Daisuke Ryû, Tats...        Akira Kurosawa
# 71    [Tim Robbins, Morgan Freeman, Bob Gunton, Clan...        Frank Darabont
# 740   [Humphrey Bogart, Walter Huston, Tim Holt, Bru...           John Huston
# 1499  [Daniel Day-Lewis, Paul Dano, Dillon Freasier,...  Paul Thomas Anderson
#
#                                                keywords  \
# 696   [new year's eve, screenwriter, jealousy, butle...
# 994   [factory, ambulance, invention, tramp, great d...
# 4     [sicily, cinema, film director, kiss, coming o...
# 1502  [bruges belgium, town square, vietnamese, cana...
# 77    [swashbuckler, evil prince, reference to socra...
# 389   [bachelor, stroke of fate, brother, oxford, au...
# 729   [assassination, gun, castle, power, kingdom, g...
# 71    [prison, corruption, police brutality, prison ...
# 740   [mexico, gold, gold rush, greed, friends, mone...
# 1499  [brother brother relationship, deaf-mute, amer...
#
#                                              genres
# 696                                         [Drama]
# 994                                 [Drama, Comedy]
# 4                                  [Drama, Romance]
# 1502                         [Comedy, Drama, Crime]
# 77    [Adventure, Family, Fantasy, Comedy, Romance]
# 389                                [Drama, Romance]
# 729                        [Action, Drama, History]
# 71                                   [Drama, Crime]
# 740             [Action, Adventure, Drama, Western]
# 1499                                        [Drama]

# %%
df_user = ( df_small.loc[ df_small['userId'] == user_id ].
           merge(df_md_small,on = 'movieId').
           sort_values('rating', ascending=False) )
df_user[ ['userId', 'title', 'rating', 'genres', 'vote_average', 'cast', 'director'] ]
# Out:
#     userId                        title  rating  \
# 41      50   Terminator 2: Judgment Day     5.0
# 0       50                    GoldenEye     4.0
# 15      50                     Outbreak     4.0
# 44      50             Independence Day     4.0
# 37      50             Schindler's List     4.0
# 35      50                Jurassic Park     4.0
# 31      50                         Dave     4.0
# 26      50                     Maverick     4.0
# 25      50                     The Mask     4.0
# 24      50  Four Weddings and a Funeral     4.0
# 20      50      While You Were Sleeping     4.0
# 16      50                 Pulp Fiction     4.0
# 23      50                 Forrest Gump     4.0
# 8       50                 Crimson Tide     4.0
# 9       50   Die Hard: With a Vengeance     4.0
# 5       50                   Braveheart     4.0
# 13      50   Interview with the Vampire     3.0
# 36      50                    The Piano     3.0
# 32      50               Demolition Man     3.0
# 33      50                     The Firm     3.0
# 34      50                 The Fugitive     3.0
# 4       50                 Broken Arrow     3.0
# 30      50                  Cliffhanger     3.0
# 38      50         Sleepless in Seattle     3.0
# 39      50                    Tombstone     3.0
# 40      50                        Ghost     3.0
# 3       50                        Se7en     3.0
# 42      50           Dances with Wolves     3.0
# 43      50                 Pretty Woman     3.0
# 6       50                    Apollo 13     3.0
# 29      50        Beverly Hills Cop III     3.0
# 14      50                         Nell     3.0
# 28      50                    True Lies     3.0
# 27      50                        Speed     3.0
# 7       50                        Congo     3.0
# 1       50                   Get Shorty     3.0
# 22      50     Clear and Present Danger     3.0
# 10      50                      The Net     3.0
# 19      50  What's Eating Gilbert Grape     3.0
# 18      50                     Stargate     3.0
# 17      50               The Specialist     3.0
# 11      50                   Waterworld     3.0
# 45      50                       Eraser     3.0
# 21      50   Ace Ventura: Pet Detective     2.0
# 2       50                     Clueless     2.0
# 12      50              Dumb and Dumber     1.0
#
#                                                genres  vote_average  \
# 41                [Action, Thriller, Science Fiction]           7.7
# 0                       [Adventure, Action, Thriller]           6.6
# 15         [Action, Drama, Science Fiction, Thriller]           6.4
# 44               [Action, Adventure, Science Fiction]           6.7
# 37                              [Drama, History, War]           8.3
# 35                       [Adventure, Science Fiction]           7.6
# 31                                           [Comedy]           6.3
# 26        [Action, Adventure, Comedy, Drama, Western]           6.6
# 25                  [Romance, Comedy, Crime, Fantasy]           6.6
# 24                           [Comedy, Drama, Romance]           6.6
# 20                           [Comedy, Drama, Romance]           6.5
# 16                                  [Thriller, Crime]           8.3
# 23                           [Comedy, Drama, Romance]           8.2
# 8                           [Action, Thriller, Drama]           7.0
# 9                                  [Action, Thriller]           6.9
# 5                       [Action, Drama, History, War]           7.7
# 13                                  [Horror, Romance]           7.2
# 36                                   [Drama, Romance]           7.1
# 32                   [Crime, Action, Science Fiction]           6.4
# 33                         [Drama, Mystery, Thriller]           6.6
# 34      [Adventure, Action, Thriller, Crime, Mystery]           7.2
# 4                [Action, Adventure, Drama, Thriller]           5.7
# 30                      [Action, Adventure, Thriller]           6.1
# 38                           [Comedy, Drama, Romance]           6.5
# 39       [Action, Adventure, Drama, History, Western]           7.4
# 40       [Fantasy, Drama, Thriller, Mystery, Romance]           6.9
# 3                          [Crime, Mystery, Thriller]           8.1
# 42                        [Adventure, Drama, Western]           7.6
# 43                                  [Romance, Comedy]           7.0
# 6                                             [Drama]           7.3
# 29                            [Action, Comedy, Crime]           5.5
# 14                                  [Drama, Thriller]           6.1
# 28                                 [Action, Thriller]           6.8
# 27                         [Action, Adventure, Crime]           6.8
# 7   [Action, Adventure, Drama, Mystery, Science Fi...           5.0
# 1                           [Comedy, Thriller, Crime]           6.4
# 22                          [Action, Drama, Thriller]           6.4
# 10          [Crime, Drama, Mystery, Thriller, Action]           5.6
# 19                                   [Romance, Drama]           7.5
# 18               [Action, Adventure, Science Fiction]           6.8
# 17                                 [Action, Thriller]           5.5
# 11                                [Adventure, Action]           5.9
# 45                 [Action, Drama, Mystery, Thriller]           5.6
# 21                                  [Comedy, Mystery]           6.4
# 2                            [Comedy, Drama, Romance]           6.9
# 12                                           [Comedy]           6.5
#
#                                                  cast            director
# 41  [Arnold Schwarzenegger, Linda Hamilton, Robert...       James Cameron
# 0   [Pierce Brosnan, Sean Bean, Izabella Scorupco,...     Martin Campbell
# 15  [Dustin Hoffman, Rene Russo, Morgan Freeman, K...   Wolfgang Petersen
# 44  [Will Smith, Bill Pullman, Jeff Goldblum, Mary...     Roland Emmerich
# 37  [Liam Neeson, Ben Kingsley, Ralph Fiennes, Car...    Steven Spielberg
# 35  [Sam Neill, Laura Dern, Jeff Goldblum, Richard...    Steven Spielberg
# 31  [Kevin Kline, Sigourney Weaver, Frank Langella...        Ivan Reitman
# 26  [Mel Gibson, Jodie Foster, James Garner, Graha...      Richard Donner
# 25  [Jim Carrey, Cameron Diaz, Nancy Fish, Tim Bag...       Chuck Russell
# 24  [Hugh Grant, Andie MacDowell, James Fleet, Sim...         Mike Newell
# 20  [Sandra Bullock, Bill Pullman, Peter Gallagher...      Jon Turteltaub
# 16  [John Travolta, Samuel L. Jackson, Uma Thurman...   Quentin Tarantino
# 23  [Tom Hanks, Robin Wright, Gary Sinise, Mykelti...     Robert Zemeckis
# 8   [Denzel Washington, Gene Hackman, Matt Craven,...          Tony Scott
# 9   [Bruce Willis, Jeremy Irons, Samuel L. Jackson...      John McTiernan
# 5   [Mel Gibson, Catherine McCormack, Sophie Marce...          Mel Gibson
# 13  [Brad Pitt, Tom Cruise, Kirsten Dunst, Antonio...         Neil Jordan
# 36  [Holly Hunter, Harvey Keitel, Sam Neill, Anna ...        Jane Campion
# 32  [Sylvester Stallone, Wesley Snipes, Sandra Bul...     Marco Brambilla
# 33  [Tom Cruise, Jeanne Tripplehorn, Gene Hackman,...      Sydney Pollack
# 34  [Harrison Ford, Tommy Lee Jones, Sela Ward, Ju...        Andrew Davis
# 4   [John Travolta, Christian Slater, Samantha Mat...            John Woo
# 30  [Sylvester Stallone, John Lithgow, Michael Roo...        Renny Harlin
# 38  [Tom Hanks, Meg Ryan, Bill Pullman, Ross Malin...         Nora Ephron
# 39  [Kurt Russell, Val Kilmer, Sam Elliott, Bill P...  George P. Cosmatos
# 40  [Patrick Swayze, Demi Moore, Whoopi Goldberg, ...        Jerry Zucker
# 3   [Brad Pitt, Morgan Freeman, Gwyneth Paltrow, J...       David Fincher
# 42  [Kevin Costner, Mary McDonnell, Graham Greene,...       Kevin Costner
# 43  [Julia Roberts, Richard Gere, Ralph Bellamy, J...      Garry Marshall
# 6   [Tom Hanks, Bill Paxton, Kevin Bacon, Gary Sin...          Ron Howard
# 29  [Eddie Murphy, Judge Reinhold, Héctor Elizondo...         John Landis
# 14  [Jodie Foster, Liam Neeson, Natasha Richardson...       Michael Apted
# 28  [Arnold Schwarzenegger, Jamie Lee Curtis, Tom ...       James Cameron
# 27  [Keanu Reeves, Dennis Hopper, Sandra Bullock, ...         Jan de Bont
# 7   [Laura Linney, Dylan Walsh, Ernie Hudson, Tim ...      Frank Marshall
# 1   [John Travolta, Gene Hackman, Rene Russo, Dann...    Barry Sonnenfeld
# 22  [Harrison Ford, Willem Dafoe, Anne Archer, Joa...       Phillip Noyce
# 10  [Sandra Bullock, Jeremy Northam, Dennis Miller...       Irwin Winkler
# 19  [Johnny Depp, Leonardo DiCaprio, Juliette Lewi...     Lasse Hallström
# 18  [Kurt Russell, James Spader, Jaye Davidson, Vi...     Roland Emmerich
# 17  [Sylvester Stallone, Sharon Stone, James Woods...          Luis Llosa
# 11  [Kevin Costner, Chaim Girafi, Rick Aviles, R. ...      Kevin Reynolds
# 45  [Arnold Schwarzenegger, James Caan, Vanessa Wi...       Chuck Russell
# 21  [Jim Carrey, Sean Young, Courteney Cox, Tone L...         Tom Shadyac
# 2   [Alicia Silverstone, Stacey Dash, Brittany Mur...      Amy Heckerling
# 12  [Jim Carrey, Jeff Daniels, Lauren Holly, Teri ...      Peter Farrelly
